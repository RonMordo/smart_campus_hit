# %%
import pandas as pd

df = pd.read_csv('~/Documents/Projects/data_science/smart_campus_hit/data/main_data_frame_cleaned.csv')
df.head()
# Out:
#                                      id   created_time  \
# 0  31090670-587f-11ee-87d4-cff6bc55cfcd  1695301380183
# 1  1b7e5fe0-1a8a-11ee-a00e-098052e37df7  1688489096414
# 2  9f7cfcd0-a897-11ed-aa55-4bc57f85b6ff  1675960468765
# 3  cb519810-5180-11ee-87d4-cff6bc55cfcd  1694532410385
# 4  eb4f3c40-a897-11ed-aa55-4bc57f85b6ff  1675960595972
#
#                                      additional_info additional_info_1  \
# 0  gateway:false:overwriteActivityTime:false:desc...           gateway
# 1  gateway:false:overwriteActivityTime:false:desc...           gateway
# 2  gateway:false:overwriteActivityTime:false:desc...           gateway
# 3  gateway:false:overwriteActivityTime:false:desc...           gateway
# 4  gateway:false:overwriteActivityTime:false:desc...           gateway
#
#    additional_info_2      additional_info_3  additional_info_4  \
# 0              False  overwriteActivityTime              False
# 1              False  overwriteActivityTime              False
# ...
